# %% [markdown]
# # Problems on Linear Algebra
#
# - Gabriel Wendell Celestino Rocha
# ---

# %% [markdown]
# ## Required Libraries

# %%
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# ## Theoretical Problems

# %% [markdown]
# $$
# \boxed{\text{Coming soon... =)}}
# $$

# %% [markdown]
# ---

# %% [markdown]
# ## Programming Problems

# %% [markdown]
# ### $\star$ Problem 6 : Eigenvalues of a Matrix
#
# Write a Python function that calculates the eigenvalues of a $2\times2$ matrix. The function should return a list containing the eigenvalues, sort values from highest to lowest.

# %%
def calculate_eigenvalues(matrix: list[list[float|int]]) -> list[float]:
    # Your Code Here
    return eigenvalues

# %% [markdown]
# **Hint :** The eigenvalues of the matrix are calculated using the characteristic equation of the matrix, which for a $2\times2$ matrix is $\lambda^{2}-\text{tr}\left(A\right)\lambda+\text{det}\left(A\right)=0$, where $\lambda$ are the eigenvalues.

# %% [markdown]
# $$
# \Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond
# $$

# %% [markdown]
# ### $\star$ Problem 7 : Matrix Transformation
#
# Write a Python function that transforms a given matrix $A$ using the operation $T^{-1}AS$, where T and S are invertible matrices. The function should first validate if the matrices $T$ and $S$ are invertible, and then perform the transformation. In cases where there is no solution return $-1$.

# %%
def transform_matrix(A: list[list[int|float]], T: list[list[int|float]], S: list[list[int|float]]) -> list[list[int|float]]:
    # Your Code Here
    return transformed_matrix

# %% [markdown]
# **Hint :** The matrices $T$ and $S$ are used to transform matrix $A$ by computing $T^{-1}AS$.

# %% [markdown]
# $$
# \Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond
# $$

# %% [markdown]
# ### $\star$ Problem 8 : Correlation Matrix
#
# Write a Python function to calculate the correlation matrix for a given dataset. The function should take in a 2D numpy array `X` and an optional 2D numpy array `Y`. If Y is not provided, the function should calculate the correlation matrix of `X` with itself. It should return the correlation matrix as a 2D numpy array.

# %%
def calculate_correlation_matrix(X, Y = None):
    # Your Code Here
    pass

# %% [markdown]
# **Hint :** The function calculates the correlation matrix for the dataset `X`. In this example, the correlation between the two features is $1$, indicating a perfect linear relationship.

# %% [markdown]
# $$
# \Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond
# $$

# %% [markdown]
# ### $\star$$\star$ Problem 9 : Singular Value Decomposition (SVD)
#
# Write a Python function called `svd_2x2_singular_values(A)` that finds an approximate singular value decomposition of a real $2 \times 2$ matrix using one Jacobi rotation.
#
# - **Input :** `A`: a NumPy array of shape `(2, 2)`.
#
# - **Rules :** You may use basic NumPy operations (matrix multiplication, transpose, element wise math, etc.). Do not call `numpy.linalg.svd` or any other high-level SVD routine. Stick to a single Jacobi step no iterative refinements.
#
# - **Return :** A tuple `(U, Î£, V_T)` where `U` is a $2\times2$ orthogonal matrix, `Î£` is a length $2$ NumPy array containing the singular values, and `V_T` is the transpose of the right-singular-vector matrix `V`.

# %%
def svd_2x2_singular_values(A: np.ndarray) -> tuple:
    # Your Code Here
    return SVD

# %% [markdown]
# **Hint :** `U` is the first matrix, `sigma` is the second vector and `V` is the third matrix.

# %% [markdown]
# $$
# \Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond
# $$

# %% [markdown]
# ### $\star$$\star$ Problem 10 : SVD of a $2\times2$ Matrix using eigenvalues $\&$ eigenvectors
#
# Given a $2\times2$ matrix, write a Python function to compute its Singular Value Decomposition (SVD). The function should return the matrices `U`, `S`, and `V` such that `A = U * S * V`, use the method described in this [post](https://metamerist.blogspot.com/2006/10/linear-algebra-for-graphics-geeks-svd.html).

# %%
def svd_2x2(A: np.ndarray) -> tuple:
    # Your Code Here
    pass

# %% [markdown]
# **Hint :** The SVD of the matrix $A$ is calculated using the eigenvalues and eigenvectors of $A^T$ A and $A A^T$. The singular values are the square roots of the eigenvalues, and the eigenvectors form the columns of matrices $U$ and $V$.

# %% [markdown]
# $$
# \Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond\quad\quad\Diamond
# $$

# %% [markdown]
# ---
